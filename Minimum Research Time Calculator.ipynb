# %% [markdown]
# # Warzone 2100 Minimum Research Time Calculator

# %%
print(f'Updated on {datetime.datetime.now().astimezone().strftime("%B %d, %Y at %H:%M:%S UTC%z %Z")}')
with pd.option_context('display.max_rows', None): display(mrt)
# Out:
# Updated on December 01, 2024 at 21:21:37 UTC-0500 Eastern Standard Time
#                                     Technology Minimum Research Time
# 0                                   Mortar Pit                  0:24
# 1                             Heavy Machinegun                  0:47
# 2                          Medium Body - Cobra                  0:47
# 3                      Cyborg Composite Alloys                  0:47
# 4                   Heavy Machinegun Hardpoint                  1:10
# 5                             Composite Alloys                  1:10
# 6                             HE Mortar Shells                  1:10
# 7                               HE Rockets Mk2                  1:33
# 8                          Heavy Repair Turret                  1:33
# 9              Synaptic Link Data Analysis Mk2                  1:33
# 10                             Repair Facility                  1:33
# 11                     Automated Manufacturing                  1:33
# 12                      HEAT Cannon Shells Mk2                  1:35
# 13             High Temperature Flamer Gel Mk3                  1:36
# 14                            Light Body - Bug                  1:52
# 15                               Medium Cannon                  2:12
# 16                 Cyborg Composite Alloys Mk2                  2:12
# 17                            Hover Propulsion                  2:12
# 18                      Improved Hardcrete Mk3                  2:12
# 19                     Medium Cannon Hardpoint                  2:37
# 20                           Mini-Rocket Array                  2:50
# 21                           Rocket Autoloader                  2:50
# 22                   Automated Repair Facility                  2:50
# 23                   Fuel Injection Engine Mk3                  2:50
# 24                        Composite Alloys Mk2                  3:10
# 25                        HE Mortar Shells Mk2                  3:10
# 26                         Mini-Rocket Battery                  3:16
# 27                              HE Rockets Mk3                  3:29
# 28                   Mortar Targeting Computer                  3:29
# 29             Synaptic Link Data Analysis Mk3                  3:29
# 30                          Stabilized Rockets                  3:29
# 31                        APDSB MG Bullets Mk3                  3:29
# 32                            Chaingun Upgrade                  3:29
# 33                      HEAT Cannon Shells Mk3                  3:30
# 34                    Cannon Laser Rangefinder                  3:30
# 35                 Cyborg Composite Alloys Mk3                  4:02
# 36                          Tracked Propulsion                  4:19
# 37                         Heavy Body - Python                  4:19
# 38                      Medium Body - Scorpion                  4:19
# 39                            Lancer AT Rocket                  5:09
# 40                         Superhot Flamer Gel                  5:12
# 41                            Lancer Hardpoint                  5:34
# 42                                Lancer Tower                  5:34
# 43               Thermal Imaging Mortar Shells                  5:42
# 44                        Composite Alloys Mk3                  5:42
# 45                       Rocket Autoloader Mk2                  5:42
# 46       Dedicated Synaptic Link Data Analysis                  5:42
# 47                         Rapid Fire Chaingun                  5:42
# 48                        Cyborg Thermal Armor                  5:42
# 49                                VTOL Factory                  5:42
# 50                       Hyper Velocity Cannon                  5:44
# 51                         Heavy Body - Mantis                  5:57
# 52           Hyper Velocity Cannon Emplacement                  6:06
# 53             Hyper Velocity Cannon Hardpoint                  6:06
# 54                        APFSDS Cannon Rounds                  6:13
# 55                   Rotary Mortar - Pepperpot                  6:26
# 56                              Sensor Upgrade                  6:26
# 57                        HE Mortar Shells Mk3                  6:26
# 58                      Heavy Mortar - Bombard                  6:26
# 59                        Light Body - Leopard                  6:41
# 60                  Tungsten-Tipped MG Bullets                  6:41
# 61                                 Bombard Pit                  6:51
# 62                               Pepperpot Pit                  6:51
# 63                         HEAT Rocket Warhead                  7:10
# 64                         Hurricane AA Turret                  7:10
# 65                            Cyborg Transport                  7:10
# 66                        Bunker Buster Rocket                  7:10
# 67                           Mortar Autoloader                  7:10
# 68                              Radar Detector                  7:15
# 69                       Robotic Manufacturing                  7:30
# 70                           Hurricane AA Site                  7:35
# 71                               Thermal Armor                  7:40
# 72                     Cannon Laser Designator                  7:40
# 73                        Improved Engineering                  7:40
# 74                    Sunburst AA Rocket Array                  7:40
# 75                    Cyborg Thermal Armor Mk2                  7:40
# 76                           Cannon Autoloader                  7:50
# 77               Cyborg Dense Composite Alloys                  7:59
# 78                            Sunburst AA Site                  8:04
# 79                             VTOL Propulsion                  8:09
# 80   Dedicated Synaptic Link Data Analysis Mk2                  8:09
# 81            Target Acquisition Mortar Shells                  8:09
# 82                       Gas Turbine Generator                  8:09
# 83                                 Assault Gun                  8:09
# 84                      AA Cyclone Flak Cannon                  8:10
# 85                      Heavy Flamer - Inferno                  8:11
# 86                                   CB Turret                  8:22
# 87                        Turbo-Charged Engine                  8:31
# 88            AA Cyclone Flak Cannon Hardpoint                  8:32
# 89          AA Cyclone Flak Cannon Emplacement                  8:32
# 90                            Rotary MG Bunker                  8:33
# 91                       Assault Gun Hardpoint                  8:33
# 92                              Inferno Bunker                  8:33
# 93                      Dense Composite Alloys                  8:44
# 94                             Super Transport                  8:44
# 95                                    CB Tower                  8:46
# 96                     Superhot Flamer Gel Mk2                  8:55
# 97               Improved Rocket Wire Guidance                  9:01
# 98                    APFSDS Cannon Rounds Mk2                  9:02
# 99                           VTOL Rearming Pad                  9:27
# 100                    HEAT Rocket Warhead Mk2                  9:27
# 101                         Sensor Upgrade Mk2                  9:27
# 102                      Rocket Autoloader Mk3                  9:27
# 103                         Super Heavy-Gunner                  9:27
# 104                      Mortar Autoloader Mk2                  9:27
# 105                             Assault Cannon                  9:37
# 106             Tungsten-Tipped MG Bullets Mk2                  9:40
# 107                    Robotic Repair Facility                  9:45
# 108                                 Supercrete                  9:53
# 109                   Cyborg Thermal Armor Mk3                  9:53
# 110                          Incendiary Mortar                  9:55
# 111                         HEAP Mortar Shells                  9:58
# 112                   Assault Cannon Hardpoint                 10:01
# 113                      Cannon Autoloader Mk2                 10:03
# 114                           Cluster Bomb Bay                 10:08
# 115                          Thermal Armor Mk2                 10:15
# 116                Hyper Fire Chaingun Upgrade                 10:19
# 117                  Gas Turbine Generator Mk2                 10:19
# 118                      Flamer Autoloader Mk2                 10:21
# 119                      Incendiary Mortar Pit                 10:21
# 120                      Medium Body - Panther                 10:28
# 121          Cyborg Dense Composite Alloys Mk2                 10:45
# 122                           Super HVC Cyborg                 10:54
# 123                             Ripple Rockets                 10:58
# 124  Dedicated Synaptic Link Data Analysis Mk3                 11:03
# 125                   Super Auto-Cannon Cyborg                 11:04
# 126                    Rocket Laser Designator                 11:11
# 127                    Automated VTOL Rearming                 11:11
# 128                         Heavy Rocket Array                 11:34
# 129                      Mortar Autoloader Mk3                 11:40
# 130                   Turbo-Charged Engine Mk2                 11:42
# 131                       Heavy Rocket Battery                 11:58
# 132                         VTOL Strike Turret                 11:58
# 133                    HEAT Rocket Warhead Mk3                 11:58
# 134          Hardened Base Structure Materials                 11:58
# 135                   APFSDS Cannon Rounds Mk3                 11:59
# 136                 Dense Composite Alloys Mk2                 12:06
# 137                               Heavy Cannon                 12:07
# 138                  Gas Turbine Generator Mk3                 12:21
# 139                          VTOL Strike Tower                 12:21
# 140                     Heavy Cannon Hardpoint                 12:30
# 141                      Ripple Rocket Battery                 12:33
# 142                          Phosphor Bomb Bay                 12:35
# 143                             HE Bomb Shells                 12:35
# 144                             Supercrete Mk2                 12:37
# 145             Tungsten-Tipped MG Bullets Mk3                 12:41
# 146                      Cannon Autoloader Mk3                 12:46
# 147                    Superhot Flamer Gel Mk3                 12:47
# 148                      Flamer Autoloader Mk3                 13:02
# 149                     HEAP Mortar Shells Mk2                 13:06
# 150                         Tank Killer Rocket                 13:08
# 151                Automated VTOL Rearming Mk2                 13:08
# 152                          Thermal Armor Mk3                 13:16
# 153                        Twin Assault Cannon                 13:21
# 154                           Twin Assault Gun                 13:24
# 155                    Thermal Imaging Rockets                 13:32
# 156                    Tank Killer Emplacement                 13:32
# 157                      Tank Killer Hardpoint                 13:32
# 158                 Twin Assault Cannon Bunker                 13:45
# 159                 Twin Assault Gun Hardpoint                 13:48
# 160          Cyborg Dense Composite Alloys Mk3                 13:55
# 161                                   Howitzer                 14:12
# 162              Neural Synapse Research Brain                 14:19
# 163                   Super Tank-Killer Cyborg                 14:26
# 164                        Whirlwind AA Turret                 14:33
# 165                             VTOL CB Turret                 14:40
# 166                        HESH Rocket Warhead                 14:40
# 167                         Mortar Fast Loader                 14:52
# 168                              HEAP Bomb Bay                 14:53
# 169                              Plasma Cannon                 14:55
# 170                          Whirlwind AA Site                 14:56
# 171                        Whirlwind Hardpoint                 14:56
# 172                     HVAPFSDS Cannon Rounds                 15:03
# 173                     Command Turret Upgrade                 15:04
# 174                              VTOL CB Tower                 15:04
# 175                   Turbo-Charged Engine Mk3                 15:13
# 176                            Cannon Fortress                 15:16
# 177                  Plasma Cannon Emplacement                 15:18
# 178                          Thermite Bomb Bay                 15:29
# 179                      Improved Bomb Warhead                 15:29
# 180                         Heavy Body - Tiger                 15:30
# 181                       Howitzer Emplacement                 15:38
# 182                Automated VTOL Rearming Mk3                 15:38
# 183                Depleted Uranium MG Bullets                 15:45
# 184                             Supercrete Mk3                 15:45
# 185                 Dense Composite Alloys Mk3                 15:45
# 186                         HE Howitzer Shells                 16:00
# 187                     HEAP Mortar Shells Mk3                 16:01
# 188        Cyborg High Intensity Thermal Armor                 16:20
# 189        Target Acquisition Artillery Shells                 16:21
# 190                            Plasmite Flamer                 16:28
# 191                         Sensor Upgrade Mk3                 16:28
# 192                     Plasmite Flamer Bunker                 16:51
# 193                    Vapor Turbine Generator                 17:00
# 194                        Incendiary Howitzer                 17:11
# 195                Rotary Howitzer - Hellstorm                 17:11
# 196                     AA Tornado Flak Cannon                 17:18
# 197         Cyborg Superdense Composite Alloys                 17:25
# 198                    HESH Rocket Warhead Mk2                 17:32
# 199         AA Tornado Flak Cannon Emplacement                 17:41
# 200           AA Tornado Flak Cannon Hardpoint                 17:41
# 201          Neural Synapse Research Brain Mk2                 17:53
# 202                        Cannon Rapid Loader                 18:01
# 203                 HVAPFSDS Cannon Rounds Mk2                 18:14
# 204                     HE Howitzer Shells Mk2                 18:20
# 205                      Robotic VTOL Rearming                 18:33
# 206                         Laser - Flashlight                 18:33
# 207            Incendiary Howitzer Emplacement                 18:33
# 208                      Hellstorm Emplacement                 18:37
# 209            Depleted Uranium MG Bullets Mk2                 18:42
# 210                      Advanced Bomb Warhead                 18:44
# 211                       Wide Spectrum Sensor                 18:52
# 212               High Intensity Thermal Armor                 18:56
# 213                     Flashlight Emplacement                 18:56
# 214    Target Acquisition Artillery Shells Mk2                 19:00
# 215                            Scourge Missile                 19:09
# 216    Cyborg High Intensity Thermal Armor Mk2                 19:12
# 217                                 Needle Gun                 19:13
# 218                 Wide Spectrum Sensor Tower                 19:15
# 219                      Scourge Missile Tower                 19:32
# 220                  Scourge Missile Hardpoint                 19:32
# 221                           Needle Gun Tower                 19:36
# 222                Superdense Composite Alloys                 19:38
# 223                          Nexus Link Turret                 19:51
# 224                      Superhot Plasmite Gel                 20:11
# 225                           Nexus Link Tower                 20:14
# 226                Vapor Turbine Generator Mk2                 20:21
# 227                    HESH Rocket Warhead Mk3                 20:31
# 228                       Advanced Engineering                 20:31
# 229                       Super Scourge Cyborg                 20:31
# 230                       Heavy Rocket Bastion                 20:50
# 231                       EMP Missile Launcher                 20:55
# 232                     HE Howitzer Shells Mk3                 21:04
# 233     Cyborg Superdense Composite Alloys Mk2                 21:10
# 234                    Cannon Rapid Loader Mk2                 21:17
# 235                 HVAPFSDS Cannon Rounds Mk3                 21:30
# 236                   Light Body - Retaliation                 21:36
# 237          Neural Synapse Research Brain Mk3                 21:43
# 238                  Robotic VTOL Rearming Mk2                 21:49
# 239                                Auto-Repair                 21:49
# 240                                 EMP Cannon                 21:49
# 241            Depleted Uranium MG Bullets Mk3                 21:55
# 242                              Plasmite Bomb                 22:01
# 243         Target Prediction Artillery Shells                 22:02
# 244                       EMP Cannon Hardpoint                 22:12
# 245             Heavy Howitzer - Ground Shaker                 22:14
# 246    Cyborg High Intensity Thermal Armor Mk3                 22:25
# 247                    Hi-Energy Laser Emitter                 22:25
# 248                    Improved Laser Focusing                 22:25
# 249           High Intensity Thermal Armor Mk2                 22:25
# 250                                Avenger SAM                 22:59
# 251         Advanced Missile Allocation System                 22:59
# 252                         Hardened Rail Dart                 23:02
# 253                         Gas Turbine Engine                 23:05
# 254                   Advanced Repair Facility                 23:08
# 255                           Avenger SAM Site                 23:21
# 256                          Avenger Hardpoint                 23:21
# 257                Vapor Turbine Generator Mk3                 23:29
# 258                                  Plascrete                 23:38
# 259            Superdense Composite Alloys Mk2                 23:44
# 260                  Ground Shaker Emplacement                 23:45
# 261                  Superhot Plasmite Gel Mk2                 24:08
# 262                     Advanced Manufacturing                 24:26
# 263                    Cannon Rapid Loader Mk3                 24:51
# 264     Cyborg Superdense Composite Alloys Mk3                 25:09
# 265                  Robotic VTOL Rearming Mk3                 25:21
# 266                                 EMP Mortar                 25:21
# 267                             EMP Mortar Pit                 25:44
# 268                       HEAP Howitzer Shells                 25:52
# 269                        Howitzer Autoloader                 25:52
# 270            Cyborg Superdense Thermal Armor                 25:57
# 271                       Thermopole Energizer                 26:03
# 272                                Pulse Laser                 26:03
# 273           High Intensity Thermal Armor Mk3                 26:13
# 274                  Nexus Resistance Circuits                 26:16
# 275                          Pulse Laser Tower                 26:26
# 276                      Pulse Laser Hardpoint                 26:26
# 277                       Seraph Missile Array                 26:37
# 278                   Advanced Missile Warhead                 26:37
# 279          Advanced Base Structure Materials                 26:40
# 280            Rail Target Prediction Computer                 26:41
# 281                     Seraph Missile Battery                 27:00
# 282                              Plascrete Mk2                 27:10
# 283                   Super Pulse Laser Cyborg                 27:19
# 284                  Medium Body - Retribution                 27:22
# 285                    Satellite Uplink Center                 27:53
# 286            Superdense Composite Alloys Mk3                 28:11
# 287                  Superhot Plasmite Gel Mk3                 28:29
# 288             Self-Replicating Manufacturing                 29:17
# 289                Hi-Energy Laser Emitter Mk2                 29:42
# 290        Cyborg Superdense Thermal Armor Mk2                 30:00
# 291                 Target Prediction Missiles                 30:15
# 292     Advanced Missile Allocation System Mk2                 30:15
# 293                     Hardened Rail Dart Mk2                 30:19
# 294                               Rail Gun ROF                 30:19
# 295           Vehicle Superdense Thermal Armor                 30:30
# 296                     Gas Turbine Engine Mk2                 31:10
# 297                              Plascrete Mk3                 31:13
# 298                      Heavy Plasma Launcher                 31:25
# 299                   HEAP Howitzer Shells Mk2                 33:08
# 300                    Howitzer Autoloader Mk2                 33:08
# 301                      Stormbringer AA Laser                 33:20
# 302                   Thermopole Energizer Mk2                 33:20
# 303                   Stormbringer Emplacement                 33:43
# 304               Advanced Missile Warhead Mk2                 33:53
# 305        Cyborg Superdense Thermal Armor Mk3                 34:33
# 306                                Heavy Laser                 35:09
# 307       Vehicle Superdense Thermal Armor Mk2                 35:18
# 308                     Heavy Body - Vengeance                 35:27
# 309                    Heavy Laser Emplacement                 35:32
# 310                                   Plasteel                 35:45
# 311                  Search & Destroy Missiles                 37:31
# 312                           Rail Gun ROF Mk2                 37:35
# 313                                   Rail Gun                 37:35
# 314                         Rail Gun Hardpoint                 37:58
# 315                       Rail Gun Emplacement                 37:58
# 316          Heavy Plasma Launcher Emplacement                 38:41
# 317                          Super Rail-Gunner                 38:58
# 318                     Gas Turbine Engine Mk3                 39:45
# 319                Hi-Energy Laser Emitter Mk3                 40:36
# 320       Vehicle Superdense Thermal Armor Mk3                 40:36
# 321     Advanced Missile Allocation System Mk3                 41:10
# 322                          Archangel Missile                 41:10
# 323                               Plasteel Mk2                 41:19
# 324               Laser Satellite Command Post                 42:10
# 325                    Howitzer Autoloader Mk3                 44:03
# 326                   HEAP Howitzer Shells Mk3                 44:03
# 327                   Thermopole Energizer Mk3                 44:14
# 328               Advanced Missile Warhead Mk3                 44:48
# 329                        Heavy Body - Wyvern                 47:01
# 330                               Plasteel Mk3                 47:22
# 331                  Archangel Missile Battery                 48:26
# 332                               Gauss Cannon                 48:30
# 333                           Rail Gun ROF Mk3                 48:30
# 334                     Hardened Rail Dart Mk3                 48:30
# 335                     Gauss Cannon Hardpoint                 48:52
# 336                   Gauss Cannon Emplacement                 48:52
# 337                             Vindicator SAM                 52:04
# 338                       Vindicator Hardpoint                 52:27
# 339                        Vindicator SAM Site                 52:27
# 340                           Missile Fortress                 53:47
# 341                 Multi Turret Body - Dragon                 57:56
# 342                       Howitzer Fast Loader                 58:20
# 343                       Mass Driver Fortress               1:01:07

# %% [markdown]
# ## Fetch data

# %%
import pandas as pd
import requests
r = requests.get('https://raw.githubusercontent.com/Warzone2100/warzone2100/master/data/mp/stats/research.json')
df = pd.DataFrame.from_dict(r.json())

r = requests.get('https://raw.githubusercontent.com/Warzone2100/warzone2100/master/data/mp/stats/structure.json')
sdf = pd.DataFrame.from_dict(r.json())

# %% [markdown]
# ## Set starting technologies
# Depending on the game settings, some technologies are already researched at the start of the game.

# %%
starting_technologies = [
    # Default tech
    'R-Sys-Spade1Mk1',            # Construction Unit
    'R-Vehicle-Body01',           # Light Body - Viper
    'R-Vehicle-Prop-Wheels',      # Wheeled Propulsion
    
    # T1 Advanced Bases
    'R-Wpn-Cannon-Damage01',      # HEAT Cannon Shells
    'R-Struc-Research-Upgrade01', # Synaptic Link Data Analysis
    'R-Wpn-Flamer-Damage02',      # High Temperature Flamer Gel Mk2
    'R-Wpn-Flamer-ROF01',         # Flamer Autoloader
    'R-Wpn-MG-Damage03',          # APDSB MG Bullets Mk2
    'R-Vehicle-Engine02',         # Fuel Injection Engine Mk2
    'R-Struc-Factory-Module',     # Factory Module
    'R-Wpn-Mortar01Lt',           # Mortar
    'R-Wpn-Rocket-Damage01',      # HE Rockets
    'R-Sys-MobileRepairTurret01', # Mobile Repair Turret
    'R-Defense-WallUpgrade02',    # Improved Hardcrete Mk2
    'R-Vehicle-Prop-Halftracks',  # Half-tracked Propulsion
    'R-Comp-CommandTurret01',     # Command Turret
    'R-Struc-Materials01',        # Reinforced Base Structure Materials
    'R-Defense-TankTrap01',       # Tank Traps
    'R-Defense-HardcreteGate',    # Hardcrete Gate
    'R-Sys-Sensor-Tower02',       # Hardened Sensor Tower
    'R-Defense-Tower01',          # Heavy Machinegun Guard Tower 
    'R-Defense-Tower06',          # Mini-Rocket Tower
    'R-Defense-Pillbox01',        # Heavy Machinegun Bunker
    'R-Defense-Pillbox04',        # Light Cannon Bunker
    'R-Defense-Pillbox05',        # Flamer Bunker
    'R-Defense-WallTower02',      # Light Cannon Hardpoint
]

def zero_out(tech):
    df.loc['researchPoints', tech] = 0
    reqs = df[tech]['requiredResearch']
    
    if not isinstance(reqs, list): # Base case
        return
    
    for child in reqs:
        zero_out(child)
    
for tech in starting_technologies:
    zero_out(tech)

# %% [markdown]
# ## Calculate the minimum research time

# %% [markdown]
# This function uses a recursive branching algorithm to calculate the cumulative number of research points a technology needs, including pre-requisite technologies.

# %%
def branch(tech):
    if tech is None:
        return None
    
    r_points = df[tech]['researchPoints']
    reqs = df[tech]['requiredResearch']
    
    if not isinstance(reqs, list): # Base case
        return r_points
    
    max_r_points = 0
    
    for child in reqs: # Branch
        child_r_points = branch(child)
        
        if child_r_points > max_r_points:
            max_r_points = child_r_points
    
    return r_points + max_r_points

# %% [markdown]
# To accurately convert research points into time, the different research rates given by research upgrades is needed.

# %%
import math

upgrade_table = [
    {
        'technology': None,
        'rate': sdf['A0ResearchFacility']['researchPoints'],
        'module_rate': None,
        'max_rate': sdf['A0ResearchFacility']['researchPoints']
    },
    {
        'technology': 'R-Struc-Research-Module',
        'rate': sdf['A0ResearchFacility']['researchPoints']
    },
    {'technology': 'R-Struc-Research-Upgrade01'},
    {'technology': 'R-Struc-Research-Upgrade02'},
    {'technology': 'R-Struc-Research-Upgrade03'},
    {'technology': 'R-Struc-Research-Upgrade04'},
    {'technology': 'R-Struc-Research-Upgrade05'},
    {'technology': 'R-Struc-Research-Upgrade06'},
    {'technology': 'R-Struc-Research-Upgrade07'},
    {'technology': 'R-Struc-Research-Upgrade08'},
    {'technology': 'R-Struc-Research-Upgrade09'}
]

for i in range(len(upgrade_table)):
    if 'rate' not in upgrade_table[i]:
        percentIncrease = df[upgrade_table[i]['technology']]['results'][0]['value'] / 100
        extra = math.ceil(sdf['A0ResearchFacility']['researchPoints'] * percentIncrease)
        upgrade_table[i]['rate'] = upgrade_table[i-1]['rate'] + extra

    if 'module_rate' not in upgrade_table[i]:
        upgrade_table[i]['module_rate'] = upgrade_table[i]['rate'] + sdf['A0ResearchFacility']['moduleResearchPoints']
    
    if 'max_rate' not in upgrade_table[i]:
        upgrade_table[i]['max_rate'] = max(upgrade_table[i]['rate'], upgrade_table[i]['module_rate'])

    upgrade_table[i]['inflection_point'] = branch(upgrade_table[i]['technology'])

# %% [markdown]
# This function converts research points into seconds, and takes research upgrades into consideration.

# %%
def calc(points):
    # Identify how many upgrades we currently have, based on the starting technologies
    upgrades = 0
    
    for i, element in enumerate(upgrade_table[::-1]):
        if element['technology'] in starting_technologies:
            upgrades = 10 - i
            break;

    pointsDone = 0
    seconds = 0
    rate = upgrade_table[upgrades]['max_rate']
    
    while pointsDone < points:
        
        if upgrades < 10 and pointsDone > upgrade_table[upgrades + 1]['inflection_point']:
            upgrades += 1
            rate = upgrade_table[upgrades]['max_rate']
        
        pointsDone += rate
        seconds += 1

    return seconds

# %% [markdown]
# We will need a quick function to convert seconds into a readable format (e.g. `132` → `2:12`).

# %%
import datetime

def format_time(s):
    hours, remainder = divmod(s, 3600)
    minutes, seconds = divmod(remainder, 60)
    
    if hours > 0:
        return f'{hours}:{minutes:02}:{seconds:02}'
    else:
        return f'{minutes}:{seconds:02}'

# %% [markdown]
# Now, we can calculate the minimum research time for every technology.

# %%
mrt = pd.DataFrame({'id': list(df.columns)})
mrt['Technology'] = mrt['id'].apply(lambda x: df[x]['name'])
mrt['Minimum Research Time'] = mrt['id'].apply(lambda x: calc(branch(x)))
mrt = mrt[mrt['Minimum Research Time'] != 0]
mrt = mrt.sort_values(by=['Minimum Research Time'])
mrt = mrt.reset_index(drop=True)
mrt = mrt.drop(columns=['id'])
mrt['Minimum Research Time'] = mrt['Minimum Research Time'].apply(lambda x: format_time(x))
